# %% [markdown]
# <a href="https://colab.research.google.com/github/CodenameCookie/JSON_TO_CSV.ipynb/blob/main/(New_)JSON_TO_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pandas.io.json import json_normalize

# %%
import json

# %%
import csv

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#df = pd.read_json("/content/drive/MyDrive/JSONS/dictlistV0.json")

# %%
with open('/content/drive/MyDrive/JSONS/dictlistV0.json') as json_data: 
  data = json.load(json_data)

# %%
data
# Out:
# {'0': [0.022874032768110435, -11.632877985636393, 147.0049031575521],
#  '1': [0.05576290190219879, -11.626611391703287, 147.07306416829428],
#  '2': [0.11775507032871246, -11.628006299336752, 147.00484212239584],
#  '3': [0.025681414796660345, -11.619559605916342, 147.21463012695312],
#  '4': [0.15262233714262644, -11.620052337646484, 147.072998046875],
#  '5': [0.21375259260336557, -11.618768056233725, 147.00466918945312],
#  '6': [0.06094178417697549, -11.615623474121094, 147.28789774576822],
#  '7': [0.12589053809642792, -11.614721298217773, 147.21448771158853],
#  '8': [0.029680122155696154, -11.61320940653483, 147.44433085123697],
#  '9': [0.24969103435675302, -11.609275499979654, 147.07200622558594],
#  '10': [0.3091343144575755, -11.605700810750326, 147.0035146077474],
#  '11': [0.16322443385918936, -11.609469095865885, 147.2876434326172],
#  '12': [0.22589467465877533, -11.605307579040527, 147.21349080403647],
# ...

# %%
jn = json_normalize(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(type(jn))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
''' For ref only
df = pd.DataFrame(jn).T
compression_opts = dict(method='zip',
                        archive_name='out.csv')  
df.to_csv('out4.zip', index=True,
          compression=compression_opts)  
'''
# Out:
# " For ref only\ndf = pd.DataFrame(jn).T\ncompression_opts = dict(method='zip',\n                        archive_name='out.csv')  \ndf.to_csv('out4.zip', index=True,\n          compression=compression_opts)  \n"

# %%
#df = pd.DataFrame(jn).T
df2 = pd.DataFrame.from_dict(data, orient='index')
print(df2)
###https://stackoverflow.com/questions/64925771/valueerror-arrays-must-all-be-same-length-while-converting-dictionary-to-data-f
# Out:
#               0          1           2         3
# 0      0.022874 -11.632878  147.004903       NaN
# 1      0.055763 -11.626611  147.073064       NaN
# 2      0.117755 -11.628006  147.004842       NaN
# 3      0.025681 -11.619560  147.214630       NaN
# 4      0.152622 -11.620052  147.072998       NaN
# ...         ...        ...         ...       ...
# 64089  1.934493 -10.601615  153.785426       NaN
# 64090  1.955113 -10.623594  153.857346       NaN
# 64091  1.948340 -10.582287  153.798467       NaN
# 64092  1.992908 -10.587645  153.872421       NaN
# 64093  1.976696 -10.571857  153.837128  1.976696
#
# [64094 rows x 4 columns]

# %%
compression_opts = dict(method='zip',
                        archive_name='out1.csv')  
df2.to_csv('out7777.zip', index=True,
          compression=compression_opts)

# %%
'''
with open('countries2.csv', 'w', encoding='UTF8') as f:
    writer = csv.writer(f)

    # write the data
    writer.writerow(jn)

    # write the header
    #writer.writerow(header)

    # write the data
    #writer.writerow(data)
'''
